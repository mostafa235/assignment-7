# %%
import requests

# %%
response=requests.request('GET','https://www.metaweather.com/api/location/1521894/')
data=response.json()

# %%
data
# Out:
# {'consolidated_weather': [{'id': 5685564947824640,
#    'weather_state_name': 'Light Cloud',
#    'weather_state_abbr': 'lc',
#    'wind_direction_compass': 'N',
#    'created': '2021-10-19T16:34:23.082828Z',
#    'applicable_date': '2021-10-19',
#    'min_temp': 18.68,
#    'max_temp': 29.095,
#    'the_temp': 27.665,
#    'wind_speed': 6.82629679917018,
#    'wind_direction': 353.547629438162,
#    'air_pressure': 1020.5,
#    'humidity': 46,
#    'visibility': 13.606164996420901,
#    'predictability': 70},
#   {'id': 4792769290698752,
#    'weather_state_name': 'Light Cloud',
#    'weather_state_abbr': 'lc',
#    'wind_direction_compass': 'NNW',
#    'created': '2021-10-19T16:34:25.771672Z',
#    'applicable_date': '2021-10-20',
#    'min_temp': 18.814999999999998,
#    'max_temp': 29.33,
#    'the_temp': 27.165,
#    'wind_speed': 7.4966602605689445,
#    'wind_direction': 344.8337798246335,
#    'air_pressure': 1021.5,
#    'humidity': 45,
#    'visibility': 13.298586256263421,
#    'predictability': 70},
#   {'id': 5034461730177024,
#    'weather_state_name': 'Clear',
#    'weather_state_abbr': 'c',
#    'wind_direction_compass': 'N',
#    'created': '2021-10-19T16:34:29.364907Z',
#    'applicable_date': '2021-10-21',
#    'min_temp': 18.155,
#    'max_temp': 28.689999999999998,
#    'the_temp': 26.689999999999998,
#    'wind_speed': 6.38434921189321,
#    'wind_direction': 354.8628520030165,
#    'air_pressure': 1020.5,
#    'humidity': 44,
#    'visibility': 13.878325578620855,
#    'predictability': 68},
#   {'id': 5202439939555328,
#    'weather_state_name': 'Clear',
#    'weather_state_abbr': 'c',
#    'wind_direction_compass': 'N',
#    'created': '2021-10-19T16:34:31.683171Z',
#    'applicable_date': '2021-10-22',
#    'min_temp': 17.915,
#    'max_temp': 28.73,
#    'the_temp': 27.065,
#    'wind_speed': 7.332776679946446,
#    'wind_direction': 353.5,
#    'air_pressure': 1019.0,
#    'humidity': 45,
#    'visibility': 13.593737572576154,
#    'predictability': 68},
#   {'id': 4991663857467392,
#    'weather_state_name': 'Clear',
#    'weather_state_abbr': 'c',
#    'wind_direction_compass': 'NNE',
#    'created': '2021-10-19T16:34:34.662963Z',
#    'applicable_date': '2021-10-23',
#    'min_temp': 18.39,
#    'max_temp': 28.605,
#    'the_temp': 27.0,
#    'wind_speed': 7.223609159182375,
#    'wind_direction': 26.0,
#    'air_pressure': 1019.5,
#    'humidity': 47,
#    'visibility': 13.59063071661497,
#    'predictability': 68},
#   {'id': 5638780699541504,
#    'weather_state_name': 'Clear',
#    'weather_state_abbr': 'c',
#    'wind_direction_compass': 'NNE',
#    'created': '2021-10-19T16:34:38.253323Z',
#    'applicable_date': '2021-10-24',
#    'min_temp': 17.335,
#    'max_temp': 28.265,
#    'the_temp': 25.09,
#    'wind_speed': 6.169654020520163,
#    'wind_direction': 31.5,
#    'air_pressure': 1018.0,
#    'humidity': 47,
#    'visibility': 9.999726596675416,
#    'predictability': 68}],
#  'time': '2021-10-19T20:08:34.105332+02:00',
#  'sun_rise': '2021-10-19T05:59:34.264665+02:00',
#  'sun_set': '2021-10-19T17:19:54.677015+02:00',
#  'timezone_name': 'LMT',
#  'parent': {'title': 'Egypt',
#   'location_type': 'Country',
#   'woeid': 23424802,
#   'latt_long': '26.837090,30.796391'},
#  'sources': [{'title': 'BBC',
#    'slug': 'bbc',
#    'url': 'http://www.bbc.co.uk/weather/',
#    'crawl_rate': 360},
#   {'title': 'Forecast.io',
#    'slug': 'forecast-io',
#    'url': 'http://forecast.io/',
#    'crawl_rate': 480},
#   {'title': 'HAMweather',
#    'slug': 'hamweather',
#    'url': 'http://www.hamweather.com/',
#    'crawl_rate': 360},
#   {'title': 'Met Office',
#    'slug': 'met-office',
#    'url': 'http://www.metoffice.gov.uk/',
#    'crawl_rate': 180},
#   {'title': 'OpenWeatherMap',
#    'slug': 'openweathermap',
#    'url': 'http://openweathermap.org/',
#    'crawl_rate': 360},
#   {'title': 'Weather Underground',
#    'slug': 'wunderground',
#    'url': 'https://www.wunderground.com/?apiref=fc30dc3cd224e19b',
#    'crawl_rate': 720},
#   {'title': 'World Weather Online',
#    'slug': 'world-weather-online',
#    'url': 'http://www.worldweatheronline.com/',
#    'crawl_rate': 360}],
#  'title': 'Cairo',
#  'location_type': 'City',
#  'woeid': 1521894,
#  'latt_long': '30.049950,31.248600',
#  'timezone': 'Africa/Cairo'}

# %%
for weather in data["consolidated_weather"]:
    print(f"the_temp {weather['the_temp']}\n humidity {weather['humidity']} \n visibility {weather['visibility']} \n wind_speed {weather['wind_speed']} \n air_pressure {weather['air_pressure']} \ndata {weather['applicable_date']}")
    print("-------------------------------------------------------------")
# Out:
# the_temp 27.665
#  humidity 46
#  visibility 13.606164996420901
#  wind_speed 6.82629679917018
#  air_pressure 1020.5
# data 2021-10-19
# -------------------------------------------------------------
# the_temp 27.165
#  humidity 45
#  visibility 13.298586256263421
#  wind_speed 7.4966602605689445
#  air_pressure 1021.5
# data 2021-10-20
# -------------------------------------------------------------
# the_temp 26.689999999999998
#  humidity 44
#  visibility 13.878325578620855
#  wind_speed 6.38434921189321
#  air_pressure 1020.5
# data 2021-10-21
# -------------------------------------------------------------
# the_temp 27.065
#  humidity 45
#  visibility 13.593737572576154
#  wind_speed 7.332776679946446
#  air_pressure 1019.0
# data 2021-10-22
# -------------------------------------------------------------
# the_temp 27.0
#  humidity 47
#  visibility 13.59063071661497
#  wind_speed 7.223609159182375
#  air_pressure 1019.5
# data 2021-10-23
# -------------------------------------------------------------
# the_temp 25.09
#  humidity 47
#  visibility 9.999726596675416
#  wind_speed 6.169654020520163
#  air_pressure 1018.0
# data 2021-10-24
# -------------------------------------------------------------

# %%
data["time"]
# Out:
# '2021-10-19T20:08:34.105332+02:00'

# %%
import csv
from  dateutil.parser import parse

# %%
with open('weather.csv','a',newline='') as f:
    writer=csv.DictWriter(f,fieldnames=['date','time','temperature','humidity','visibility','wind_speed','air_pressure'])
    writer.writeheader()
    for weather in data["consolidated_weather"]:
        date=parse(weather['applicable_date']).date()
        
        n=parse(data["time"])
        x=str(n.hour)
        x1=str(n.minute)
        x2=str(n.second)
        x3=x+":"+x1+":"+x2
        x3
        time=datetime.strptime(x3,"%H:%M:%S").time()
        
        temperature=weather['the_temp']
        humidity=weather['humidity']
        visibility=weather['visibility']
        wind_speed=weather['wind_speed']
        air_pressure=weather['air_pressure']
       
        writer.writerow({'date':date,'time':time,'temperature':temperature,'humidity':humidity,'visibility':visibility,'wind_speed':wind_speed,'air_pressure':air_pressure})

# %%
import pandas as pd

# %%
d=pd.read_csv("weather.csv")

# %%
d.head(10)
# Out:
#          date      time  temperature  humidity  visibility  wind_speed  \
# 0  2021-10-19  20:08:34       27.665        46   13.606165    6.826297
# 1  2021-10-20  20:08:34       27.165        45   13.298586    7.496660
# 2  2021-10-21  20:08:34       26.690        44   13.878326    6.384349
# 3  2021-10-22  20:08:34       27.065        45   13.593738    7.332777
# 4  2021-10-23  20:08:34       27.000        47   13.590631    7.223609
# 5  2021-10-24  20:08:34       25.090        47    9.999727    6.169654
#
#    air_pressure
# 0        1020.5
# 1        1021.5
# 2        1020.5
# 3        1019.0
# 4        1019.5
# 5        1018.0
